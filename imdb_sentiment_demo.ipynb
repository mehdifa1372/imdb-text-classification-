# %% [markdown]
# # IMDb transformer sentiment demo
#
# This notebook is a lightweight interface to the tested package in `src/`. Training is intentionally not started automatically because a full IMDb run requires substantial compute.

# %%
# %pip install -e .

# %%
from imdb_sentiment import SentimentAnalyzer

analyzer = SentimentAnalyzer(model_name="distilbert-base-uncased")

# %% [markdown]
# ## Optional training
#
# Uncomment the next cell when a GPU runtime is available. The command creates a validation split and keeps the official test split for final evaluation.

# %%
# metrics = analyzer.train(output_dir="artifacts", epochs=3, batch_size=8, seed=42)
# metrics

# %% [markdown]
# ## Inference
#
# After training—or after placing a compatible checkpoint in `artifacts/final_model`—load it and classify a review.

# %%
# analyzer.load_model("artifacts/final_model")
# analyzer.predict_sentiment("The performances were excellent.")
